# %% [markdown]
# ### Instructor Demo: Simple Moving Averages
#
# This program reads in the CSV datasets of Netflix (NFLX) and plots the 20, 50, and 100 Simple Moving Averages (SMA) using the `rolling` function, `window` parameter, and `mean` function.

# %%
# Import libraries and dependencies
import pandas as pd
from pathlib import Path
# %matplotlib inline

# %% [markdown]
# ### Read CSV in as DataFrame

# %%
# Set file path
csv_data = Path("../Resources/nflx.csv")

# Read the CSV into a DataFrame and set the 'date' column as a datetime index
nflx_df = pd.read_csv(csv_data, index_col="date", infer_datetime_format=True, parse_dates=True)

# Sort the data in forward chronological order, and display a few records
nflx_df.sort_index(inplace=True)
nflx_df.head(10)
# Out:
#              close
# date
# 2009-05-18  5.5386
# 2009-05-19  5.6614
# 2009-05-20  5.7500
# 2009-05-21  5.5871
# 2009-05-22  5.5429
# 2009-05-26  5.7271
# 2009-05-27  5.5614
# 2009-05-28  5.5057
# 2009-05-29  5.6314
# 2009-06-01  5.8486

# %% [markdown]
# ### Plot Daily Closing Price of NFLX

# %%
# Plot DataFrame
nflx_df.plot()
# Out:
# <AxesSubplot:xlabel='date'>

# %% [markdown]
# ### Calculate 20-Day Simple Moving Average (SMA20)

# %%
df_20 = nflx_df.rolling(window=20).mean()
df_20.head(20)
# Out:
#                close
# date
# 2009-05-18       NaN
# 2009-05-19       NaN
# 2009-05-20       NaN
# 2009-05-21       NaN
# 2009-05-22       NaN
# 2009-05-26       NaN
# 2009-05-27       NaN
# 2009-05-28       NaN
# 2009-05-29       NaN
# 2009-06-01       NaN
# 2009-06-02       NaN
# 2009-06-03       NaN
# 2009-06-04       NaN
# 2009-06-05       NaN
# 2009-06-08       NaN
# 2009-06-09       NaN
# 2009-06-10       NaN
# 2009-06-11       NaN
# 2009-06-12       NaN
# 2009-06-15  5.610495

# %%
# Calculate 20-day Simple Moving Average for NFLX Closing Prices
# Out:
#                  close
# date
# 2019-05-16         NaN
# 2019-05-15         NaN
# 2019-05-14         NaN
# 2019-05-13         NaN
# 2019-05-10         NaN
# 2019-05-09         NaN
# 2019-05-08         NaN
# 2019-05-07         NaN
# 2019-05-06         NaN
# 2019-05-03         NaN
# 2019-05-02         NaN
# 2019-05-01         NaN
# 2019-04-30         NaN
# 2019-04-29         NaN
# 2019-04-26         NaN
# 2019-04-25         NaN
# 2019-04-24         NaN
# 2019-04-23         NaN
# 2019-04-22         NaN
# 2019-04-18  368.236000
# 2019-04-17  368.007500
# 2019-04-16  368.231000
# 2019-04-15  368.394000
# 2019-04-12  368.688000
# 2019-04-11  369.018500
# 2019-04-10  369.077000
# 2019-04-09  369.094000
# 2019-04-08  368.641500
# 2019-04-05  367.982500
# 2019-04-04  367.125000
# ...                ...
# 2009-06-29    6.027075
# 2009-06-26    6.017575
# 2009-06-25    6.009790
# 2009-06-24    5.960720
# 2009-06-23    5.919935
# 2009-06-22    5.889725
# 2009-06-19    5.866650
# 2009-06-18    5.846435
# 2009-06-17    5.819790
# 2009-06-16    5.772790
# 2009-06-15    5.736075
# 2009-06-12    5.705005
# 2009-06-11    5.688360
# 2009-06-10    5.673435
# 2009-06-09    5.675650
# 2009-06-08    5.675720
# 2009-06-05    5.671505
# 2009-06-04    5.677145
# 2009-06-03    5.676285
# 2009-06-02    5.675070
# 2009-06-01    5.673215
# 2009-05-29    5.666430
# 2009-05-28    5.648070
# 2009-05-27    5.643355
# 2009-05-26    5.647065
# 2009-05-22    5.634565
# 2009-05-21    5.616850
# 2009-05-20    5.609280
# 2009-05-19    5.603780
# 2009-05-18    5.610495
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Calculate 50-Day Simple Moving Average (SMA50)

# %%
# Calculate 50-day Simple Moving Average for NFLX Closing Prices
df_50 = nflx_df.rolling(window=50).mean()
df_50[40:60]
# Out:
#                close
# date
# 2009-07-15       NaN
# 2009-07-16       NaN
# 2009-07-17       NaN
# 2009-07-20       NaN
# 2009-07-21       NaN
# 2009-07-22       NaN
# 2009-07-23       NaN
# 2009-07-24       NaN
# 2009-07-27       NaN
# 2009-07-28  5.811200
# 2009-07-29  5.822428
# 2009-07-30  5.833800
# 2009-07-31  5.844342
# 2009-08-03  5.861086
# 2009-08-04  5.876456
# 2009-08-05  5.888514
# 2009-08-06  5.901572
# 2009-08-07  5.920030
# 2009-08-10  5.938260
# 2009-08-11  5.952974

# %% [markdown]
# ### Calculate 100-Day Simple Moving Average (SMA100)

# %%
df_100 = nflx_df.rolling(window=100).mean()
df_100[95:105]
# Out:
#                close
# date
# 2009-10-01       NaN
# 2009-10-02       NaN
# 2009-10-05       NaN
# 2009-10-06       NaN
# 2009-10-07  6.095000
# 2009-10-08  6.105385
# 2009-10-09  6.115785
# 2009-10-12  6.124085
# 2009-10-13  6.134628
# 2009-10-14  6.147870

# %%
# Calculate 100-day Simple Moving Average for NFLX Closing Prices
# Out:
#                close
# date
# 2019-05-16       NaN
# 2019-05-15       NaN
# 2019-05-14       NaN
# 2019-05-13       NaN
# 2019-05-10       NaN
# 2019-05-09       NaN
# 2019-05-08       NaN
# 2019-05-07       NaN
# 2019-05-06       NaN
# 2019-05-03       NaN
# 2019-05-02       NaN
# 2019-05-01       NaN
# 2019-04-30       NaN
# 2019-04-29       NaN
# 2019-04-26       NaN
# 2019-04-25       NaN
# 2019-04-24       NaN
# 2019-04-23       NaN
# 2019-04-22       NaN
# 2019-04-18       NaN
# 2019-04-17       NaN
# 2019-04-16       NaN
# 2019-04-15       NaN
# 2019-04-12       NaN
# 2019-04-11       NaN
# 2019-04-10       NaN
# 2019-04-09       NaN
# 2019-04-08       NaN
# 2019-04-05       NaN
# 2019-04-04       NaN
# ...              ...
# 2009-06-29  6.658858
# 2009-06-26  6.629743
# 2009-06-25  6.603529
# 2009-06-24  6.575329
# 2009-06-23  6.548729
# 2009-06-22  6.521744
# 2009-06-19  6.497729
# 2009-06-18  6.475029
# 2009-06-17  6.452943
# 2009-06-16  6.426429
# 2009-06-15  6.403572
# 2009-06-12  6.380843
# 2009-06-11  6.357900
# 2009-06-10  6.335629
# 2009-06-09  6.312329
# 2009-06-08  6.291286
# 2009-06-05  6.269786
# 2009-06-04  6.249129
# 2009-06-03  6.228572
# 2009-06-02  6.216486
# 2009-06-01  6.206615
# 2009-05-29  6.192986
# 2009-05-28  6.176900
# 2009-05-27  6.162528
# 2009-05-26  6.147870
# 2009-05-22  6.134628
# 2009-05-21  6.124085
# 2009-05-20  6.115785
# 2009-05-19  6.105385
# 2009-05-18  6.095000
#
# [2517 rows x 1 columns]

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and SMAs

# %%
axis = nflx_df.plot(figsize=(25,10))
df_20.plot(ax=axis)
df_50.plot(ax=axis)
df_100.plot(ax=axis)
ax.legend(["Original", "SMA20", "SMA50", "SMA100"]);

# %%
# Set figure of the daily closing prices of NFLX


# Overlay SMA20, SMA50, and SMA100 on the same figure


# Set the legend of the figure

# %% [markdown]
# ### Overlay Daily Closing Prices of NFLX and STDs

# %%
# Set figure of the daily closing prices of NFLX
df_100 = nflx_df.rolling(window=100).std()
df_50 = nflx_df.rolling(window=50).std()
df_20 = nflx_df.rolling(window=20).std()
# Overlay STD20, STD50, and STD100 on the same figure
axis = nflx_df.plot(figsize = (25,10))
df_100 = nflx_df.rolling(window=100).std().plot(ax=axis)
df_50 = nflx_df.rolling(window=50).std().plot(ax=axis)
df_20 = nflx_df.rolling(window=20).std().plot(ax=axis)
# Set the legend of the figure

# %% [markdown]
# ### Should Harold's firm invest long term in NFLX?
